# %%
def dichotomy (f, a, b, E, mode):
    res = []
    m = (a + b) / 2
    res.append (m)
    while ((b - a) / 2 >= E):
        if (abs (f (m)) <= E):
            if (mode == 0):
                return m
            return res
        if (f (m) * f (a) < 0):
            b = m
        elif (f (m) * f (b) < 0):
            a = m
        m = (a + b) / 2
        res.append (m)
    if (mode == 0):
        return m
    return res

def newton (f, a, b, E, mode):
    res = []
    x1 = a
    x2 = (a + b) / 2
    df = f.derivative ()
    while abs (x2 - x1) >= E:
        x1 = x2
        res.append (x1)
        x2 = x1 - f (x = x1) / df (x = x1)
    if (mode == 0):
        return x1
    return res


y(x) = x^3 - 9*x^2 + 23*x - 15

show (plot (y, xmin = 0, xmax = 6))

show ("x0(derivative)", solve (y.derivative(), x))
s = solve (y.derivative(), x)
a = float (-(2/3)*sqrt(3)+3)
b = float ((2/3)*sqrt(3)+3)

result = dichotomy (y, 0.5, a, 1e-14, 0)
show ("x1(dichotomy) = ", result)
#show (len(result))
result = dichotomy (y, a, b, 1e-14, 0)
show ("x2(dichotomy) = ", result)
#show (len(result))
result = dichotomy (y, b, 5.5, 1e-14, 0)
show ("x3(dichotomy) = ", result)
#show (len(result))

result = newton (y, 0.5, a, 1e-14, 0)
show ("x1(newton) = ", result)
#show (len(result))
result = newton (y, a, b, 1e-14, 0)
show ("x2(newton) = ", result)
#show (len(result))
result = newton (y, b, 5.5, 1e-14, 0)
show ("x3(newton) = ", result)
#show (len(result))

show ("x(solve) = ",solve(y, x))

d = dichotomy (y, 0.5, a, 1e-14, 1)

arr = []
arr.append ((plot (y, xmin = 0.5, xmax = a) + point([d[0], y(d[0])], color = "red")) + text ((r"$x={}$").format (d[0]), (d[0], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = 0.5, xmax = a) + point([d[9], y(d[9])], color = "red")) + text ((r"$x={}$").format (d[9]), (d[9], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = 0.5, xmax = a) + point([d[18], y(d[18])], color = "red")) + text ((r"$x={}$").format (d[18]), (d[18], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = 0.5, xmax = a) + point([d[27], y(d[27])], color = "red")) + text ((r"$x={}$").format (d[27]), (d[27], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = 0.5, xmax = a) + point([d[36], y(d[36])], color = "red")) + text ((r"$x={}$").format (d[36]), (d[36], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = 0.5, xmax = a) + point([d[46], y(d[46])], color = "red")) + text ((r"$x={}$").format (d[46]), (d[46], 4.7), fontsize = 9, color = "black"))
show("Dichotomy:")
show (graphics_array ([arr [0:3], arr [3:]]))

d = dichotomy (y, a, b, 1e-14, 1)
arr.clear()
arr.append ((plot (y, xmin = a, xmax = b) + point([d[0], y(d[0])], color = "red")) + text ((r"$x={}$").format (d[0]), (d[0], 4.7), fontsize = 9, color = "black"))
show (graphics_array ([arr [0:]]))

d = dichotomy (y, b, 5.5, 1e-14, 1)

arr.clear ()
arr.append ((plot (y, xmin = b, xmax = 5.5) + point([d[0], y(d[0])], color = "red")) + text ((r"$x={}$").format (d[0]), (d[0], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = b, xmax = 5.5) + point([d[9], y(d[9])], color = "red")) + text ((r"$x={}$").format (d[9]), (d[9], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = b, xmax = 5.5) + point([d[18], y(d[18])], color = "red")) + text ((r"$x={}$").format (d[18]), (d[18], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = b, xmax = 5.5) + point([d[27], y(d[27])], color = "red")) + text ((r"$x={}$").format (d[27]), (d[27], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = b, xmax = 5.5) + point([d[36], y(d[36])], color = "red")) + text ((r"$x={}$").format (d[36]), (d[36], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = b, xmax = 5.5) + point([d[46], y(d[46])], color = "red")) + text ((r"$x={}$").format (d[46]), (d[46], 4.7), fontsize = 9, color = "black"))
show (graphics_array ([arr [0:3], arr [3:]]))

d = newton (y, 0.5, a, 1e-14, 1)

arr.clear()
arr.append ((plot (y, xmin = 0.5, xmax = a) + point([d[0], y(d[0])], color = "red")) + text ((r"$x={}$").format (d[0]), (d[0], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = 0.5, xmax = a) + point([d[1], y(d[1])], color = "red")) + text ((r"$x={}$").format (d[1]), (d[1], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = 0.5, xmax = a) + point([d[2], y(d[2])], color = "red")) + text ((r"$x={}$").format (d[2]), (d[2], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = 0.5, xmax = a) + point([d[3], y(d[3])], color = "red")) + text ((r"$x={}$").format (d[3]), (d[3], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = 0.5, xmax = a) + point([d[4], y(d[4])], color = "red")) + text ((r"$x={}$").format (d[4]), (d[4], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = 0.5, xmax = a) + point([d[5], y(d[5])], color = "red")) + text ((r"$x={}$").format (d[5]), (d[5], 4.7), fontsize = 9, color = "black"))
show("Newton:")
show (graphics_array ([arr [0:3], arr [3:]]))

d = newton (y, a, b, 1e-14, 1)

arr.clear()
arr.append ((plot (y, xmin = a, xmax = b) + point([d[0], y(d[0])], color = "red")) + text ((r"$x={}$").format (d[0]), (d[0], 4.7), fontsize = 9, color = "black"))
show (graphics_array ([arr [0:]]))

d = newton (y, b, 5.5, 1e-14, 1)

arr.clear ()
arr.append ((plot (y, xmin = b, xmax = 5.5) + point([d[0], y(d[0])], color = "red")) + text ((r"$x={}$").format (d[0]), (d[0], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = b, xmax = 5.5) + point([d[1], y(d[1])], color = "red")) + text ((r"$x={}$").format (d[1]), (d[1], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = b, xmax = 5.5) + point([d[2], y(d[2])], color = "red")) + text ((r"$x={}$").format (d[2]), (d[2], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = b, xmax = 5.5) + point([d[3], y(d[3])], color = "red")) + text ((r"$x={}$").format (d[3]), (d[3], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = b, xmax = 5.5) + point([d[4], y(d[4])], color = "red")) + text ((r"$x={}$").format (d[4]), (d[4], 4.7), fontsize = 9, color = "black"))
arr.append ((plot (y, xmin = b, xmax = 5.5) + point([d[5], y(d[5])], color = "red")) + text ((r"$x={}$").format (d[5]), (d[5], 4.7), fontsize = 9, color = "black"))
show (graphics_array ([arr [0:3], arr [3:]]))

show("Interactive")

@interact
def _(step = (1, 14, 1)):
    resarr = []
    
    result = dichotomy (y, 0.5, a, pow (10, -step), 0)
    resarr.append (plot (y, xmin = 0.5, xmax = a) + point([result, y(result)], color = "red") + text ((r"$x={}$").format (result), (result, 4.7), fontsize = 9, color = "black"))

    result = dichotomy (y, a, b, pow (10, -step), 0)
    resarr.append (plot (y, xmin = a, xmax = b) + point([result, y(result)], color = "red") + text ((r"$x={}$").format (result), (result, 4.7), fontsize = 9, color = "black"))

    result = dichotomy (y, b, 5.5, pow (10, -step), 0)
    resarr.append (plot (y, xmin = b, xmax = 5.5) + point([result, y(result)], color = "red") + text ((r"$x={}$").format (result), (result, 4.7), fontsize = 9, color = "black"))
    

    result = newton (y, 0.5, a, pow (10, -step), 0)
    resarr.append (plot (y, xmin = 0.5, xmax = a) + point([result, y(result)], color = "red") + text ((r"$x={}$").format (result), (result, 4.7), fontsize = 9, color = "black"))

    result = newton (y, a, b, pow (10, -step), 0)
    resarr.append (plot (y, xmin = a, xmax = b) + point([result, y(result)], color = "red") + text ((r"$x={}$").format (result), (result, 4.7), fontsize = 9, color = "black"))

    result = newton (y, b, 5.5, pow (10, -step), 0)
    resarr.append (plot (y, xmin = b, xmax = 5.5) + point([result, y(result)], color = "red") + text ((r"$x={}$").format (result), (result, 4.7), fontsize = 9, color = "black"))
    
    show (graphics_array ([resarr [0:3], resarr [3:]]))
# Out:
# Graphics object consisting of 1 graphics primitive
# 'x0(derivative)' [x == -2/3*sqrt(3) + 3, x == 2/3*sqrt(3) + 3]
# 'x1(dichotomy) = ' 1.00000000000000
# 'x2(dichotomy) = ' 3.0
# 'x3(dichotomy) = ' 5.00000000000000
# 'x1(newton) = ' 1.00000000000000
# 'x2(newton) = ' 3.0
# 'x3(newton) = ' 5.00000000000000
# 'x(solve) = ' [x == 1, x == 5, x == 3]
# 'Dichotomy:'
# Graphics Array of size 2 x 3
# Graphics Array of size 1 x 1
# Graphics Array of size 2 x 3
# 'Newton:'
# Graphics Array of size 2 x 3
# Graphics Array of size 1 x 1
# Graphics Array of size 2 x 3
# 'Interactive'
# Interactive function <function _ at 0x7f036ad699d0> with 1 widget
#   step: IntSlider(value=7, description='step…

# %%
def mygcd(num1, num2):
    if num1 == 0:
        return (num2, 0, 1)
    else:
        div, x, y = mygcd(num2 % num1, num1)
    return (div, y - (num2 // num1) * x, x)

R.<x> = QQ["x"]

f = x^4 - 4*x^3 + 7*x^2 - 5*x + 1
g = x^5 - x^4 - x^3 + x^2 + 5*x - 5

d, a, b = mygcd(f, g)
show("mygcd(f, g) = ", d)
show("gcd(f, g) = ", gcd(f, g))
show("gcd = f*u + g*v = ", f*a + g*b)
show("Данные, полученные при помощи gcd и при помощи моей реализации расширенного алгоритма евклида отличаются коэффициентом 1936/441, который на правильность решения не влияет.")
# Out:
# 'mygcd(f, g) = ' 1936/441*x - 1936/441
# 'gcd(f, g) = ' x - 1
# 'gcd = f*u + g*v = ' 1936/441*x - 1936/441
# 'Данные, полученные при помощи gcd и при помощи моей реализации расширенного алгоритма евклида отличаются коэффициентом 1936/441, который на правильность решения не влияет.'
